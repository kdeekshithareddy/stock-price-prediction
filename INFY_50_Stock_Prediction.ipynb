# %% [markdown]
# <a href="https://colab.research.google.com/github/kdeekshithareddy/stock-price-prediction/blob/main/INFY_50_Stock_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the Libraries required

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
import pickle
import seaborn as sns

# %% [markdown]
# # Importing the dataset

# %%
data = pd.read_csv("https://raw.githubusercontent.com/adityabattula/NIFTY-50-INFY-_StockMarket/main/INFY.csv")
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#          Date      Symbol Series  Prev Close      Open      High       Low  \
# 0  2000-01-03  INFOSYSTCH     EQ    14467.75  15625.00  15625.20  15625.00
# 1  2000-01-04  INFOSYSTCH     EQ    15625.20  16800.00  16875.25  16253.00
# 2  2000-01-05  INFOSYSTCH     EQ    16855.90  15701.00  16250.00  15507.45
# 3  2000-01-06  INFOSYSTCH     EQ    15507.45  15256.65  15300.00  14266.85
# 4  2000-01-07  INFOSYSTCH     EQ    14266.85  13125.50  13125.50  13125.50
#
#        Last     Close      VWAP  Volume      Turnover  Trades  \
# 0  15625.20  15625.20  15625.18    5137  8.026657e+12     NaN
# 1  16875.25  16855.90  16646.38   56186  9.352937e+13     NaN
# 2  15507.45  15507.45  15786.38  164605  2.598516e+14     NaN
# 3  14266.85  14266.85  14462.82   81997  1.185908e+14     NaN
# 4  13125.50  13125.50  13125.50    7589  9.960942e+12     NaN
#
#    Deliverable Volume  %Deliverble
# 0                 NaN          NaN
# 1                 NaN          NaN
# ...

# %%
df.tail()
# Out:
#             Date Symbol Series  Prev Close     Open    High      Low    Last  \
# 5301  2021-04-26   INFY     EQ     1333.80  1332.25  1351.3  1321.00  1345.0
# 5302  2021-04-27   INFY     EQ     1343.55  1346.00  1353.0  1340.15  1347.5
# 5303  2021-04-28   INFY     EQ     1348.50  1358.00  1359.5  1344.60  1355.8
# 5304  2021-04-29   INFY     EQ     1356.00  1368.00  1369.0  1351.40  1356.0
# 5305  2021-04-30   INFY     EQ     1356.35  1346.30  1373.9  1345.90  1348.6
#
#         Close     VWAP   Volume      Turnover    Trades  Deliverable Volume  \
# 5301  1343.55  1343.19  7088606  9.521361e+14  130375.0           4218129.0
# 5302  1348.50  1346.89  3636115  4.897445e+14  145974.0           1871084.0
# 5303  1356.00  1353.45  4879234  6.603778e+14  137376.0           2857134.0
# 5304  1356.35  1360.05  5412357  7.361090e+14  119277.0           3130945.0
# 5305  1354.35  1361.16  8354677  1.137203e+15  131718.0           5408113.0
#
#       %Deliverble
# 5301       0.5951
# ...

# %% [markdown]
# # DATA DESCRIBED

# %%
df.describe()
# Out:
#          Prev Close          Open          High           Low          Last  \
# count   5306.000000   5306.000000   5306.000000   5306.000000   5306.000000
# mean    2584.356643   2584.665266   2626.204297   2539.065002   2581.678345
# std     1796.807396   1796.731660   1842.170527   1743.052412   1789.259360
# min      526.450000    509.250000    558.000000    509.250000    529.150000
# 25%     1216.062500   1213.675000   1233.675000   1197.925000   1215.750000
# 50%     2265.675000   2265.000000   2294.300000   2232.475000   2263.275000
# 75%     3170.562500   3174.762500   3210.037500   3124.575000   3170.750000
# max    16855.900000  16800.000000  16875.250000  16253.000000  16875.250000
#
#               Close          VWAP        Volume      Turnover        Trades  \
# count   5306.000000   5306.000000  5.306000e+03  5.306000e+03  2.456000e+03
# mean    2581.885215   2582.749548  2.622813e+06  3.855758e+14  1.118490e+05
# ...

# %%
df.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# dtype: int64

# %%
df.head()
# Out:
#          Date      Symbol Series  Prev Close      Open      High       Low  \
# 0  2000-01-03  INFOSYSTCH     EQ    14467.75  15625.00  15625.20  15625.00
# 1  2000-01-04  INFOSYSTCH     EQ    15625.20  16800.00  16875.25  16253.00
# 2  2000-01-05  INFOSYSTCH     EQ    16855.90  15701.00  16250.00  15507.45
# 3  2000-01-06  INFOSYSTCH     EQ    15507.45  15256.65  15300.00  14266.85
# 4  2000-01-07  INFOSYSTCH     EQ    14266.85  13125.50  13125.50  13125.50
#
#        Last     Close      VWAP  Volume      Turnover  Trades  \
# 0  15625.20  15625.20  15625.18    5137  8.026657e+12     NaN
# 1  16875.25  16855.90  16646.38   56186  9.352937e+13     NaN
# 2  15507.45  15507.45  15786.38  164605  2.598516e+14     NaN
# 3  14266.85  14266.85  14462.82   81997  1.185908e+14     NaN
# 4  13125.50  13125.50  13125.50    7589  9.960942e+12     NaN
#
#    Deliverable Volume  %Deliverble
# 0                 NaN          NaN
# 1                 NaN          NaN
# ...

# %%
df.drop(df.columns[[0,1,2]],axis=1,inplace=True)

# %% [markdown]
# # FILLING NULL VALUES USING MEAN

# %%
data.fillna(data.mean(),inplace=True)
# Out:
# <ipython-input-9-a64c3c260c71>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# dtype: int64

# %% [markdown]
# # DELETING FEATURES

# %%
df.tail()
# Out:
#       Prev Close     Open    High      Low    Last    Close     VWAP   Volume  \
# 5301     1333.80  1332.25  1351.3  1321.00  1345.0  1343.55  1343.19  7088606
# 5302     1343.55  1346.00  1353.0  1340.15  1347.5  1348.50  1346.89  3636115
# 5303     1348.50  1358.00  1359.5  1344.60  1355.8  1356.00  1353.45  4879234
# 5304     1356.00  1368.00  1369.0  1351.40  1356.0  1356.35  1360.05  5412357
# 5305     1356.35  1346.30  1373.9  1345.90  1348.6  1354.35  1361.16  8354677
#
#           Turnover    Trades  Deliverable Volume  %Deliverble
# 5301  9.521361e+14  130375.0           4218129.0       0.5951
# 5302  4.897445e+14  145974.0           1871084.0       0.5146
# 5303  6.603778e+14  137376.0           2857134.0       0.5856
# 5304  7.361090e+14  119277.0           3130945.0       0.5785
# 5305  1.137203e+15  131718.0           5408113.0       0.6473

# %%
df = df.drop('%Deliverble', axis=1)

# %%
df.head()
# Out:
#    Prev Close      Open      High       Low      Last     Close      VWAP  \
# 0    14467.75  15625.00  15625.20  15625.00  15625.20  15625.20  15625.18
# 1    15625.20  16800.00  16875.25  16253.00  16875.25  16855.90  16646.38
# 2    16855.90  15701.00  16250.00  15507.45  15507.45  15507.45  15786.38
# 3    15507.45  15256.65  15300.00  14266.85  14266.85  14266.85  14462.82
# 4    14266.85  13125.50  13125.50  13125.50  13125.50  13125.50  13125.50
#
#    Volume      Turnover  Trades  Deliverable Volume
# 0    5137  8.026657e+12     NaN                 NaN
# 1   56186  9.352937e+13     NaN                 NaN
# 2  164605  2.598516e+14     NaN                 NaN
# 3   81997  1.185908e+14     NaN                 NaN
# 4    7589  9.960942e+12     NaN                 NaN

# %%
df = df.drop(columns=['Trades'])

# %%
df.rename(columns = {'Prev Close':'PClose'}, inplace = True)

# %%
df.head()
# Out:
#      PClose      Open      High       Low      Last     Close      VWAP  \
# 0  14467.75  15625.00  15625.20  15625.00  15625.20  15625.20  15625.18
# 1  15625.20  16800.00  16875.25  16253.00  16875.25  16855.90  16646.38
# 2  16855.90  15701.00  16250.00  15507.45  15507.45  15507.45  15786.38
# 3  15507.45  15256.65  15300.00  14266.85  14266.85  14266.85  14462.82
# 4  14266.85  13125.50  13125.50  13125.50  13125.50  13125.50  13125.50
#
#    Volume      Turnover  Deliverable Volume
# 0    5137  8.026657e+12                 NaN
# 1   56186  9.352937e+13                 NaN
# 2  164605  2.598516e+14                 NaN
# 3   81997  1.185908e+14                 NaN
# 4    7589  9.960942e+12                 NaN

# %%
df.drop(df.columns[9:],axis=1,inplace=True)

# %%
df.head()
# Out:
#      PClose      Open      High       Low      Last     Close      VWAP  \
# 0  14467.75  15625.00  15625.20  15625.00  15625.20  15625.20  15625.18
# 1  15625.20  16800.00  16875.25  16253.00  16875.25  16855.90  16646.38
# 2  16855.90  15701.00  16250.00  15507.45  15507.45  15507.45  15786.38
# 3  15507.45  15256.65  15300.00  14266.85  14266.85  14266.85  14462.82
# 4  14266.85  13125.50  13125.50  13125.50  13125.50  13125.50  13125.50
#
#    Volume      Turnover
# 0    5137  8.026657e+12
# 1   56186  9.352937e+13
# 2  164605  2.598516e+14
# 3   81997  1.185908e+14
# 4    7589  9.960942e+12

# %%
df.isnull().sum()
# Out:
# PClose      0
# Open        0
# High        0
# Low         0
# Last        0
# Close       0
# VWAP        0
# Volume      0
# Turnover    0
# dtype: int64

# %%
plt.scatter(df.Open,df.Close)
plt.show()

# %%
plt.scatter(df.PClose,df.Close)
plt.show()

# %% [markdown]
# # Data Splitting

# %%
df.describe()
# Out:
#              PClose          Open          High           Low          Last  \
# count   5306.000000   5306.000000   5306.000000   5306.000000   5306.000000
# mean    2584.356643   2584.665266   2626.204297   2539.065002   2581.678345
# std     1796.807396   1796.731660   1842.170527   1743.052412   1789.259360
# min      526.450000    509.250000    558.000000    509.250000    529.150000
# 25%     1216.062500   1213.675000   1233.675000   1197.925000   1215.750000
# 50%     2265.675000   2265.000000   2294.300000   2232.475000   2263.275000
# 75%     3170.562500   3174.762500   3210.037500   3124.575000   3170.750000
# max    16855.900000  16800.000000  16875.250000  16253.000000  16875.250000
#
#               Close          VWAP        Volume      Turnover
# count   5306.000000   5306.000000  5.306000e+03  5.306000e+03
# mean    2581.885215   2582.749548  2.622813e+06  3.855758e+14
# std     1789.462674   1792.981289  4.202984e+06  3.808224e+14
# ...

# %%
x = df[["PClose","Open","High","Low","Last","VWAP","Turnover"]]
y = df["Close"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,random_state=0)

# %%
X_train.head()
# Out:
#        PClose     Open    High      Low    Last     VWAP      Turnover
# 2379  1721.15  1712.80  1774.9  1701.10  1768.6  1756.57  1.811246e+14
# 3827  1993.65  1993.65  1994.6  1942.00  1946.9  1954.77  4.048763e+14
# 4125  1079.90  1070.00  1079.9  1066.70  1074.5  1070.52  5.024245e+14
# 5003   777.30   774.00   778.0   769.75   773.0   772.86  2.958264e+14
# 4016  1108.55  1111.00  1113.0  1071.15  1078.8  1089.29  2.839988e+14

# %%
X_test.head()
# Out:
#        PClose      Open      High       Low      Last      VWAP      Turnover
# 3655  3548.95   3548.95   3608.00   3548.00   3596.00   3590.92  2.179260e+14
# 29    9945.75  10741.45  10741.45  10741.45  10741.45  10741.45  2.549268e+13
# 5135   948.80    947.00    952.00    939.20    948.55    946.24  5.486819e+14
# 3671  3641.30   3646.00   3690.50   3623.60   3654.00   3657.57  2.301940e+14
# 4681   683.55    688.70    695.05    673.80    680.50    679.08  4.531381e+14

# %%
Y_train.head()
# Out:
# 2379    1770.10
# 3827    1947.10
# 4125    1072.45
# 5003     773.20
# 4016    1078.65
# Name: Close, dtype: float64

# %%
df.shape
# Out:
# (5306, 9)

# %%
X_train.shape
# Out:
# (3979, 7)

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
# Out:
# [-8.58841272e-04 -5.97016949e-02  4.08427242e-02  3.57626605e-02
#   8.62392015e-01  1.21449674e-01 -3.40005801e-16]

# %%
print(regressor.intercept_)
# Out:
# 0.5072821219691832

# %%
predicted = regressor.predict(X_test)

# %%
print(predicted)
# Out:
# [ 3597.03108858 10741.41324222   948.38140289 ...  1620.58812106
#   1238.61700609   666.9844192 ]

# %%
df = pd.DataFrame(Y_test,predicted)

# %%
dfr = pd.DataFrame({"Actual_Price":Y_test,"Predicted_Price":predicted})

# %%
dfr.head()
# Out:
#       Actual_Price  Predicted_Price
# 3655       3601.00      3597.031089
# 29        10741.45     10741.413242
# 5135        947.40       948.381403
# 3671       3651.25      3655.340093
# 4681        679.95       680.466021

# %%
from matplotlib import pyplot as plt
dfr['Predicted_Price'].plot(kind='line', figsize=(8, 4), title='Predicted_Price')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
dfr['Actual_Price'].plot(kind='line', figsize=(8, 4), title='Actual_Price')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
r2_score(Y_test,predicted)
# Out:
# 0.999944186940058

# %%
mean_squared_error(Y_test,predicted)
# Out:
# 186.27873174078738

# %%
mean_absolute_error(Y_test,predicted)
# Out:
# 6.027276447548173

# %%
#fetaure scaling is done for ANN
from sklearn.preprocessing import StandardScaler
sc =StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.47885124, -0.48414008, -0.46073671, ..., -0.45314421,
#         -0.45952416, -0.57504183],
#        [-0.32654202, -0.3268171 , -0.34078051, ..., -0.35275365,
#         -0.34821153,  0.07362714],
#        [-0.83726698, -0.84421561, -0.84020669, ..., -0.8439523 ,
#         -0.84482198,  0.35642479],
#        ...,
#        [-0.51551724, -0.51931858, -0.5187219 , ..., -0.51536045,
#         -0.5163374 , -0.54986285],
#        [ 0.09419474,  0.09490484,  0.08804787, ...,  0.09098047,
#          0.09085557, -0.31211084],
#        [ 0.30924418,  0.3181315 ,  0.30759446, ...,  0.32914762,
#          0.33119986, -0.19062179]])

# %%
X_test
# Out:
# array([[ 0.54276636,  0.54441107,  0.54013585, ...,  0.57576042,
#          0.57067927, -0.46835253],
#        [ 4.11814849,  4.57341424,  4.43499936, ...,  4.59895544,
#          4.58654346, -1.02622769],
#        [-0.91054309, -0.91311618, -0.91004009, ..., -0.91486755,
#         -0.91461982,  0.49052775],
#        ...,
#        [-0.51143703, -0.51091608, -0.5085117 , ..., -0.53793847,
#         -0.52608709, -0.59956401],
#        [-0.78539801, -0.7433855 , -0.73755869, ..., -0.75237337,
#         -0.74561221,  3.42229545],
#        [-1.06925209, -1.07388419, -1.06316578, ..., -1.07344859,
#         -1.07293985,  1.15424369]])

# %%
Y_train
# Out:
# 2379    1770.10
# 3827    1947.10
# 4125    1072.45
# 5003     773.20
# 4016    1078.65
#          ...
# 4931     660.60
# 3264    2814.65
# 1653    1658.00
# 2607    2734.70
# 2732    3151.45
# Name: Close, Length: 3979, dtype: float64

# %%
X_train.shape
# Out:
# (3979, 7)

# %%
#CREATING ANN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense #useful in creatiung hidden a nd output layer
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ReLU #activation
from tensorflow.keras.layers import Dropout
from tensorflow import keras

# %%
### initializing ANN
classifier=Sequential()

# %%
### adding input layer
classifier.add(Dense(units=7,activation='relu'))

# %%
model = keras.Sequential([
    keras.layers.Dense(units=50, #no.of neurons
                       input_shape=(7,),
                       activation='sigmoid'),
    # Second hidden layer
    keras.layers.Dense(units=100, #no.of neurons
                       activation='sigmoid')
])

model.compile(
    optimizer='Adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train,Y_train, epochs=20)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-62-60bd994f3616> in <cell line: 16>()
#      14 )
#      15
# ---> 16 model.fit(X_train,Y_train, epochs=20)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ...
